# %% [markdown]
# # Desafio

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Criando variável para armazenar o caminho do diretório com os arquivos
dir_path = 'C:\\Users\Administrador\\Documents\\Modelos Personalizados do Office\\Rafael Nery - Fundamentos de Big Data e Data Analytics com Python\\005 - Desafios\\Desafio 01 - Super Atacadista\\arquivos\\vendas\\'

#os.listdir(dir_path) # Listar os arquivos dentro do caminho do diretório

# %%
# Criar uma lista vazia para armazenar os caminhos completos
res =[]

#
for path in os.listdir(dir_path):

    # Verificar se é um arquivo válido
    if os.path.isfile(dir_path + path):
        res.append(dir_path + path)


# Criar um Data Frame vazio
file_combined = pd.DataFrame()

# Estrutura para combinar os arquivos
for file in res:
    df1 = pd.read_excel(file)
    file_combined = pd.concat([file_combined, df1])

dir_final = 'C:\\Users\\Administrador\\Documents\\Modelos Personalizados do Office\\Rafael Nery - Fundamentos de Big Data e Data Analytics com Python\\005 - Desafios\\Desafio 01 - Super Atacadista\\arquivos\\'
filename = 'ArquivoCombinado.xlsx'

file_combined.to_excel(dir_final + filename)
file_combined
# Out:
#       DataEmissao DataVencimento      NFe  cdCliente  cdVendedor  cdProduto  \
# 0      2017-01-12     2017-02-22  1492762    3140218         265       1073
# 1      2017-01-12     2017-02-22  1492762    3140218         265       1420
# 2      2017-01-12     2017-02-22  1492762    3140218         265        264
# 3      2017-01-13     2017-01-29  1492719    2983332         265       1154
# 4      2017-01-13     2017-01-29  1492719    2983332         265       1527
# ...           ...            ...      ...        ...         ...        ...
# 14243  2022-03-12     2022-04-14  2173547     673190         265        202
# 14244  2022-03-12     2022-04-14  2173547     673190         265       1154
# 14245  2022-03-12     2022-04-14  2173547     673190         265        668
# 14246  2022-03-12     2022-04-14  2173547     673190         265       1527
# 14247  2022-03-13     2022-04-05  2172961    3771379         215        257
#
#        QtdItens  ValorUnitario  Peso Líquido
# ...

# %% [markdown]
# # ----------------Desafio-----------------

# %%
# Carregar a tabela Clientes
path = 'C:\\Users\\Administrador\\Documents\\Modelos Personalizados do Office\\Rafael Nery - Fundamentos de Big Data e Data Analytics com Python\\005 - Desafios\\Desafio 01 - Super Atacadista\\arquivos\\'
file = 'Dimensões.xlsx'

dfClientes = pd.read_excel(path + file, sheet_name = 'Cliente')
dfClientes.head()
# Out:
#    cdCliente                   Razão Social Status Categoria    Cidade  UF
# 0    1339104   Vinicius e Filipe Cantina ME      A  Cantinas  Curitiba  PR
# 1    1339740  Sandra e Cláudio Cantina Ltda      A  Cantinas  Curitiba  PR
# 2    1339884        Vera e Analu Cantina ME      A  Cantinas  Curitiba  PR
# 3    1340322    Emilly e Vitor Cantina Ltda      A  Cantinas  Curitiba  PR
# 4    4837795    Kaique e Rafaela Cantina ME      A  Cantinas  Curitiba  PR

# %%
path = 'C:\\Users\\Administrador\\Documents\\Modelos Personalizados do Office\\Rafael Nery - Fundamentos de Big Data e Data Analytics com Python\\005 - Desafios\\Desafio 01 - Super Atacadista\\arquivos\\'
file = 'Dimensões.xlsx'

dfProduto = pd.read_excel(path + file, sheet_name = 'Produto')
dfProduto.head()
# Out:
#    cdProduto  Descrição  cdGrupo
# 0          1  Produto 1     9999
# 1          2  Produto 2     9999
# 2          3  Produto 3     9999
# 3          4  Produto 4     9999
# 4          5  Produto 5     9999

# %%
path = 'C:\\Users\\Administrador\\Documents\\Modelos Personalizados do Office\\Rafael Nery - Fundamentos de Big Data e Data Analytics com Python\\005 - Desafios\\Desafio 01 - Super Atacadista\\arquivos\\'
file = 'Dimensões.xlsx'

dfGrupoProduto = pd.read_excel(path + file, sheet_name = 'GrupoProduto')
dfGrupoProduto.head()
# Out:
#    cdGrupo            Grupo      Linha
# 0      102      Leite em Pó  Alimentos
# 1      103         Açúcares  Alimentos
# 2      104  Doces Enlatados  Alimentos
# 3      105         Farinhas  Alimentos
# 4      106            Óleos  Alimentos

# %%
path = 'C:\\Users\\Administrador\\Documents\\Modelos Personalizados do Office\\Rafael Nery - Fundamentos de Big Data e Data Analytics com Python\\005 - Desafios\\Desafio 01 - Super Atacadista\\arquivos\\'
file = 'Dimensões.xlsx'

dfVendedor = pd.read_excel(path + file, sheet_name = 'Vendedor')
dfVendedor.head()
# Out:
#    cdVendedor          Vendedor  cdSupervisor      Supervisor  cdGerente  \
# 0         669       Kaua Araujo            15  Fernando Silva          1
# 1         660     Julieta Gomes            25     Emily Rocha          1
# 2         183    Isabella Sousa            25     Emily Rocha          1
# 3         102    Gustavo Barros            25     Emily Rocha          1
# 4         196  Leonardo Cardoso            30    Diego Araujo          1
#
#          Gerente  Equipe
# 0  Victor Castro  Varejo
# 1  Victor Castro  Varejo
# 2  Victor Castro  Varejo
# 3  Victor Castro  Varejo
# 4  Victor Castro  Varejo

# %%
path = 'C:\\Users\\Administrador\\Documents\\Modelos Personalizados do Office\\Rafael Nery - Fundamentos de Big Data e Data Analytics com Python\\005 - Desafios\\Desafio 01 - Super Atacadista\\arquivos\\'
file = 'Dimensões.xlsx'

dfData = pd.read_excel(path + file, sheet_name = 'Data')
dfData.head()
# Out:
#         Data   Ano      Mes  MesNum  Dia
# 0 2017-01-01  2017  Janeiro       1    1
# 1 2017-01-02  2017  Janeiro       1    2
# 2 2017-01-03  2017  Janeiro       1    3
# 3 2017-01-04  2017  Janeiro       1    4
# 4 2017-01-05  2017  Janeiro       1    5

# %% [markdown]
# # ANÁLISE EXPLORATÓRIA

# %% [markdown]
# ##### 2. Qual a cobertura de clientes por ano?
# (Cobertura de clientes = total de clientes que efetuaram uma compra)

# %%
# Bloco utilizado para combinar as colunas Ano, Mês, Dia e MesNum do Data Frame dfData,
# para que seja possível agregar os dados de modo a visualizar as informações por ano.

df_merge = file_combined.merge(dfData,                  # Tabela da direita (fornecedora das colunas faltantes)
                               left_on = 'DataEmissao', # Coluna que será utilizada com valor procurado na tabela da esquerda.
                               right_on = 'Data',       # Coluna da tabela da direita que será utilizada para busca
                               how = 'left')            # É a forma que os dados serão inseridos, ESQUERDA <---- DIREITA

df_merge
# Out:
#        DataEmissao DataVencimento      NFe  cdCliente  cdVendedor  cdProduto  \
# 0       2017-01-12     2017-02-22  1492762    3140218         265       1073
# 1       2017-01-12     2017-02-22  1492762    3140218         265       1420
# 2       2017-01-12     2017-02-22  1492762    3140218         265        264
# 3       2017-01-13     2017-01-29  1492719    2983332         265       1154
# 4       2017-01-13     2017-01-29  1492719    2983332         265       1527
# ...            ...            ...      ...        ...         ...        ...
# 302835  2022-03-12     2022-04-14  2173547     673190         265        202
# 302836  2022-03-12     2022-04-14  2173547     673190         265       1154
# 302837  2022-03-12     2022-04-14  2173547     673190         265        668
# 302838  2022-03-12     2022-04-14  2173547     673190         265       1527
# 302839  2022-03-13     2022-04-05  2172961    3771379         215        257
#
# ...

# %%
# Cria um novo Data Frame, considerando apenas as colunas ANO e cdCliente do file_combined
df_contagem_cliente = df_merge.loc[:,['Ano', 'cdCliente']]

# Remover a duplicata para calcular a cobertura de clientes. Sendo que para este cálculo é necessário eliminar
# os registros duplicados, considera todas as colunas
df_contagem_cliente = df_contagem_cliente.drop_duplicates()

# Agrupa os dados, por meio da contagem, separando os dados através da coluna ANO
df_contagem_cliente = df_contagem_cliente.groupby(['Ano']).count()

df_contagem_cliente
# Out:
#       cdCliente
# Ano
# 2017        599
# 2018       1232
# 2019        980
# 2020        980
# 2021        980
# 2022        980

# %%
sns.barplot(x=df_contagem_cliente.index, 
            y='cdCliente', 
            data= df_contagem_cliente, 
            orient= 'v')
# Out:
# <Axes: xlabel='Ano', ylabel='cdCliente'>

# %% [markdown]
# ##### 3. Peso líquido total vendidos por ano?

# %%
# Criando um novo Data Frama com as colunas Ano e Peso Líquido
df_peso_ano = df_merge.loc[:,['Ano','Peso Líquido']]

df_peso_ano = df_peso_ano.groupby('Ano').sum() 

df_peso_ano['Peso Tons'] = df_peso_ano['Peso Líquido']/1000

df_peso_ano
# Out:
#       Peso Líquido  Peso Tons
# Ano
# 2017     414819.40  414.81940
# 2018     658505.01  658.50501
# 2019      61465.62   61.46562
# 2020      61465.62   61.46562
# 2021      61465.62   61.46562
# 2022      61465.62   61.46562

# %%
graficos = sns.barplot(x = df_peso_ano.index, 
            y = df_peso_ano['Peso Tons']
            )

plt.title('Peso em Toneladas por Ano')

plt.xlabel('Ano')

plt.ylabel('Peso (tons)')

graficos.bar_label(graficos.containers[0])
# Out:
# [Text(0, 0, '414.819'),
#  Text(0, 0, '658.505'),
#  Text(0, 0, '61.4656'),
#  Text(0, 0, '61.4656'),
#  Text(0, 0, '61.4656'),
#  Text(0, 0, '61.4656')]

# %% [markdown]
# ##### 5. Qual foi a quantidade total de produtos vendidos em todo o período?
#
# (Crie um gráfico de colunas para mostrar o total vendido por ano)

# %%
df_produto_ano = df_merge.loc[:,['Ano','QtdItens']]

df_produto_ano = df_produto_ano.groupby('Ano').sum() 

df_produto_ano['Produto por Milhão'] = df_produto_ano['QtdItens']/1000000

df_produto_ano
# Out:
#       QtdItens  Produto por Milhão
# Ano
# 2017   2167345            2.167345
# 2018   3864838            3.864838
# 2019    348989            0.348989
# 2020    348989            0.348989
# 2021    348989            0.348989
# 2022    348989            0.348989

# %%
print(f'O Total de Produtos Vendidos é de: ', df_produto_ano['QtdItens'].sum())
# Out:
# O Total de Produtos Vendidos é de:  7428139

# %%
graf = sns.barplot(y = df_produto_ano.index, 
            x = df_produto_ano['Produto por Milhão'],
            orient= 'h'
            )

plt.title('Quantidade de Produtos Vendidos por Ano')

plt.ylabel('Ano')

plt.xlabel('Produtos Vendidos (em milhão)')

graf.bar_label(graf.containers[0])
# Out:
# [Text(0, 0, '2.16735'),
#  Text(0, 0, '3.86484'),
#  Text(0, 0, '0.348989'),
#  Text(0, 0, '0.348989'),
#  Text(0, 0, '0.348989'),
#  Text(0, 0, '0.348989')]

# %% [markdown]
# ##### 4. Qual é Total de Faturamento da Super Atacadista em todo o período?
#
# (Crie um gráfico de colunas para mostrar o total vendido por ano)

# %%
df_fat = df_merge.loc[:,['Ano','QtdItens','ValorUnitario']]

# Adicionando a coluna subtotal
df_fat['Subtotal'] = df_fat['QtdItens'] * df_fat['ValorUnitario']

# Calcular o total vendido no perído
df_fat = df_fat.loc[:,['Ano','Subtotal']]

df_fat = df_fat.groupby('Ano').sum()/1000000

df_fat
# Out:
#        Subtotal
# Ano
# 2017   6.648222
# 2018  10.214809
# 2019   1.046201
# 2020   1.046201
# 2021   1.046201
# 2022   1.046201

# %%
a = sns.barplot(x = df_fat.index,
            y = df_fat['Subtotal'])

plt.title('Faturamento Total do Super Atacadista')

plt.xlabel('Ano')

plt.ylabel('Valor Total (em milhão)')

a.bar_label(a.containers[0])
# Out:
# [Text(0, 0, '6.64822'),
#  Text(0, 0, '10.2148'),
#  Text(0, 0, '1.0462'),
#  Text(0, 0, '1.0462'),
#  Text(0, 0, '1.0462'),
#  Text(0, 0, '1.0462')]

# %% [markdown]
# ##### 7. Quantos clientes ativos e inativos temos em nossa empresa?
#
# (Crie um gráfico de rosca para mostrar estes totais)

# %%
# Selecionando as colunas cdClientes e Status do Data Frame dfClientes
dfClientes_resumo = dfClientes.loc[:,['cdCliente','Status']]

# Substituir os valores na coluna status -> A - Ativo | I - Inativo
dfClientes_resumo['Status'] = dfClientes_resumo['Status'].replace('A','Ativo')
dfClientes_resumo['Status'] = dfClientes_resumo['Status'].replace('I','Inativo')

# Agrupar os dados por Inativo e Ativo

dfClientes_resumo = dfClientes_resumo.groupby('Status').count()
dfClientes_resumo
# Out:
#          cdCliente
# Status
# Ativo         1364
# Inativo         47

# %%
b = sns.barplot(x = dfClientes_resumo.index,
            y = dfClientes_resumo['cdCliente']
                                  )

plt.title('Clientes Ativos e Inativos')

plt.xlabel('Status')

plt.ylabel('Quantidade')

b.bar_label(b.containers[0])
# Out:
# [Text(0, 0, '1364'), Text(0, 0, '47')]

# %%
# Gráfico de pizza
plt.pie(dfClientes_resumo['cdCliente'], 
        labels = dfClientes_resumo.index,
        autopct = '%.0f%%'
        )

plt.title('Clientes Ativos e Inativos')
# Out:
# Text(0.5, 1.0, 'Clientes Ativos e Inativos')

# %% [markdown]
# ##### 6. Qual foi o total de peso em toneladas dos produtos vendidos em todo o período?
#
# (Crie um gráfico de colunas para mostrar o total vendido por ano)

# %%
# Seleciona a coluna Peso Líquido e realizaa soma deste valor e converte o total em toneladas
peso_vendido = file_combined['Peso Líquido'].sum() / 1000

# Trata a quantidade de casas decimais, ajustando para 2 casas após a vírgula
peso_vendido = round(peso_vendido,2)

print(f'O Peso Total vendido foi de {peso_vendido} toneladas.')
# Out:
# O Peso Total vendido foi de 1319.19 toneladas.

# %% [markdown]
# ##### 8. Qual foi o ano com maior ticket médio dos produtos?
#
# (Ticket médio = Total faturado pela quantidade vendida)

# %%
# Seleção das colunas Ano, QtdItens e ValorUnitario
dfticket = df_merge.loc[:,['QtdItens','ValorUnitario','Ano']]

# Adicionar a coluna Valor Total
dfticket['ValorTotal'] = dfticket['QtdItens'] * dfticket['ValorUnitario']

# Selecionar as colunas de interesse
dfticket = dfticket.loc[:,['Ano','QtdItens','ValorTotal']]

#Agrupar os campos QtdItens e ValorTotal por ano
dfticket = dfticket.groupby('Ano').sum()

dfticket['Ticket Médio'] = dfticket['ValorTotal'] / dfticket['QtdItens']
dfticket
# Out:
#       QtdItens   ValorTotal  Ticket Médio
# Ano
# 2017   2167345   6648222.05      3.067450
# 2018   3864838  10214809.43      2.643011
# 2019    348989   1046201.01      2.997805
# 2020    348989   1046201.01      2.997805
# 2021    348989   1046201.01      2.997805
# 2022    348989   1046201.01      2.997805
